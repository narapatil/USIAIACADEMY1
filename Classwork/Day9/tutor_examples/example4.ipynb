# %%
10 times

.4

Standard deviation (SD)


 = .5 (Goal)
    
   .5 - .4

 = .1 (SD)

# %%
 2.2 to 3.8 of sample size 100

# %%
creating the normal distribution?

# %%
Histogram

# %%
import numpy as np

# %%
np.histogram([1, 2, 1], bins=[0, 1, 2, 3])
# Out:
# (array([0, 2, 1]), array([0, 1, 2, 3]))

# %%
print(np.random.uniform(20, 60, 10))
# Out:
# [20.62158851 53.64013383 46.48964188 31.65872943 26.46330929 44.90233327
#  41.84359376 52.66314259 47.9782995  52.72875426]

# %%
sample = np.random.uniform(2.2, 3.8, 1000)

# %%
sample
# Out:
# array([3.56158893, 3.70786364, 2.48391188, 3.40738535, 2.23819159,
#        3.4441252 , 2.43160508, 3.34194479, 2.77088596, 3.29978193,
#        2.96212575, 2.6548653 , 3.06598244, 3.26775174, 3.42813848,
#        3.04064532, 2.5607298 , 3.67395218, 2.39458735, 3.19968508,
#        3.07336232, 2.84805983, 2.31750604, 2.77234815, 2.50703559,
#        2.7092586 , 2.24352024, 2.75125255, 3.00649128, 3.55256924,
#        3.45123129, 2.32293109, 3.77620337, 3.37431672, 3.55464333,
#        2.79894502, 2.25997942, 3.64586112, 2.9162462 , 2.89521744,
#        3.17307314, 2.71387656, 2.44066914, 2.41180231, 2.99223545,
#        2.92196936, 3.4988675 , 3.2433878 , 2.49703166, 3.5150196 ,
#        2.78489417, 2.65284171, 3.71735685, 3.47680289, 3.76624283,
#        2.99400359, 2.54863551, 2.58283889, 2.75388897, 3.47629399,
#        3.78738579, 2.90015942, 3.72180949, 2.42709999, 2.53542592,
#        2.39536583, 3.18955251, 3.26759309, 2.34898586, 2.22505605,
# ...

# %%
<2.5 
>=2.5 to 3
>3 to 3.5
>3.5

# %%
<2.5 = 24 / 23
2.5 to 3 =  33
3 to 3.5 = 30
>3.5 = 14

# %%
<2.5 = 181
2.5 to 3 = 339
3 to 3.5 = 302
>3.5 = 178

# %%
<2.4
2.4 to 2.6
2.6 to 2.8
2.8 to 3.0

.
.
.

# %%
CDF

181
181+339
181+339+302
181+339+302+178 = 1000 = Total Samples

# %%
When Linear Regressions = CDF
