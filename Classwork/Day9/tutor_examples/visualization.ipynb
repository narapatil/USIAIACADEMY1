# %%
import pandas as pd
data=pd.read_excel('store.xls')
someData=pd.pivot_table(data=data,index=['Sub-Category'],columns=['Region'],values='Sales',aggfunc='mean')
someData
# Out:
# Region            Central         East        South         West
# Sub-Category
# Accessories    185.552328   218.608602   213.099641   236.876419
# Appliances     191.723846   271.337032   241.053407   222.326000
# Art             32.757614    32.832298    32.786070    36.848264
# Binders        155.528093   121.586357   150.529841   118.813403
# Bookcases      483.143536   625.990486   389.262929   450.051544
# Chairs         553.445753   572.980256   513.368705   491.697237
# Copiers       2328.723125  2660.973100  1328.536571  1989.969680
# Envelopes       78.591051    59.133432    61.954741    61.464179
# Fasteners       14.146000    13.438000    17.355724    12.822444
# Furnishings     74.411561   102.725724   104.888994    98.923454
# Labels          32.256211    24.326486    36.202769    43.782121
# Machines      1276.065905  1786.653108  2993.942222  1088.310821
# Paper           54.491907    53.366672    64.031602    59.252707
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
someddata=someData.unstack().reset_index()
someddata.columns=['Region', 'Sub-Category', 'Sales']
plt.figure(figsize=(20,6))
sns.barplot(someddata['Sub-Category'],someddata['Sales'],hue=someddata['Region'])
# Out:
# /home/amarnath/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sub-Category', ylabel='Sales'>

# %%
xSeries=[1,2,3,4,6,7]
plt.plot(xSeries)

# %%
xSeries=[1,2,3,4,3,2]
plt.plot(xSeries)
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.title('Sample Graph 1')
# Out:
# Text(0.5, 1.0, 'Sample Graph 1')

# %%
import numpy as np
xSeries=np.linspace(0,100,30)
ySeries=np.random.rand(30)
# plt.style.use('seaborn-pastel')
plt.plot(xSeries,ySeries,'rH')
plt.ylabel('y axis')
plt.xlabel('x axis')
plt.title('Sample Graph 1')
# Out:
# Text(0.5, 1.0, 'Sample Graph 1')

# %%
serI=np.arange(10)
serA=np.random.random(10)*6
serB=np.random.random(10)*5
fig=plt.figure()

plt.plot(serB,'ro',serA,'c*')

# %%
kk=['A','B','C','D','a','b','c']
kk2=np.arange(7)
kk3=np.array([50,60,80,20,10,90,75])

# %%
plt.bar(kk,kk3)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.figure(figsize=(20, 5))

plt.subplot(131)
plt.bar(kk, kk3)
plt.subplot(132)
plt.scatter(kk, kk3)
plt.subplot(133)
plt.plot(kk, kk3)
plt.suptitle('Subplots with Categorical values')
# Out:
# Text(0.5, 0.98, 'Subplots with Categorical values')

# %%
plt.figure(figsize=(20,5))
plt.subplot(121)
plt.subplot(122)
# plt.subplot(133)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,3))
# plt.subplot(11)
plt.subplot(131)
plt.scatter(kk,kk3)
plt.subplot(132)
plt.plot(kk,kk3,'g*')
plt.subplot(133)
plt.plot(kk,kk3,'b*')

# %%
plt.figure(figsize=(20,10))
# plt.subplot(11)
plt.subplot(231)
plt.scatter(kk,kk3)
plt.subplot(232)
plt.plot(kk,kk3,'g*')
plt.subplot(233)
plt.bar(kk,kk3)
plt.subplot(234)
plt.plot(kk,kk3,'r|')
plt.subplot(235)
plt.plot(kk,kk3,'bH')
plt.subplot(236)
plt.plot(kk,kk3,'yh')

# %%
someScores=np.random.random(100)*100

# %%
meanVal,stdDevVal=someScores.mean(),someScores.std()

# %%
plt.hist(someScores,facecolor='g', alpha=0.75)
plt.xlabel('Scores')
plt.ylabel('OCCURENCE')
plt.title('Histogram of scores')
plt.text(20, 18, '$\mu={},\ \sigma=${}'.format(meanVal,stdDevVal))
plt.axis([0, 100, 0,22])
plt.grid(True)

# %%
plt.hist(someScores,facecolor='g', alpha=0.75)
plt.xlabel('Scores')
plt.ylabel('OCCURENCE')
plt.title('Histogram of scores')
plt.text(20, 18, '$\mu={},\ \sigma=${}'.format(meanVal,stdDevVal))
plt.axis([0, 100, 0,22])
plt.grid(True)
plt.annotate('local max', xy=(12, 12), xytext=(20, 24),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )
# Out:
# Text(20, 24, 'local max')

# %%
xSeries=np.arange(500)
plt.plot(xSeries)

# %%
xSeries=np.arange(500)
plt.plot(xSeries)
plt.yscale('log')

# %%
xSeries=np.random.random(500)
plt.plot(xSeries)
plt.yscale('logit')

# %%
xSer=np.sin(np.arange(50))

# %%
plt.plot(xSer)

# %%
plt.figure(figsize=(15,5))
plt.suptitle('A tale of 2 graphs',size=20)
plt.subplot(121)
plt.plot(xSer)
plt.title('1st graph')
plt.subplot(122)
plt.plot(xSer*3)
plt.title('2nd graph')
# Out:
# Text(0.5, 1.0, '2nd graph')

# %%
plt.scatter(xSer,np.arange(50))

# %%
catVal=['A','B','C']
vale=[23,46,12]

plt.bar(catVal,vale)
# Out:
# <BarContainer object of 3 artists>

# %%
matInfo=np.random.random(100).reshape(10,10)

# %%
matInfo
# Out:
# array([[0.44334915, 0.00739532, 0.46661528, 0.80672379, 0.51984425,
#         0.714744  , 0.26150413, 0.22299577, 0.9210033 , 0.22965432],
#        [0.94547801, 0.83518054, 0.22348538, 0.30804856, 0.42363206,
#         0.13492874, 0.73200959, 0.14790715, 0.15679921, 0.56854591],
#        [0.49280015, 0.20242105, 0.65291713, 0.11754756, 0.17913697,
#         0.93040412, 0.86959476, 0.67712651, 0.84319074, 0.90425096],
#        [0.22954493, 0.09646078, 0.98436945, 0.94083766, 0.30153155,
#         0.24899444, 0.22808453, 0.90379542, 0.33535137, 0.0286751 ],
#        [0.71560282, 0.34953711, 0.02037369, 0.29453608, 0.10009307,
#         0.87936448, 0.0705002 , 0.17753289, 0.14018557, 0.81642346],
#        [0.80742733, 0.24547215, 0.64195985, 0.77214258, 0.96056098,
#         0.81231449, 0.87670718, 0.16047636, 0.90482837, 0.94994457],
#        [0.82352846, 0.97339205, 0.94035474, 0.54383992, 0.86290453,
#         0.99160512, 0.10561194, 0.06923219, 0.40460588, 0.68273809],
# ...

# %%
matInfo.max(),matInfo.min()
# Out:
# (0.9916051157102779, 0.007395315859080931)

# %%
plt.figure(figsize=(8,8))
plt.pcolor(matInfo)
xx=matInfo.ravel()
for k in range(10):
    for l in range(10):
        plt.text(k,l,str(format(matInfo[k][l],'.1f')))

# %%
plt.hist(np.sin(np.arange(100)),orientation='horizontal',density=True)
# Out:
# (array([1.00004897, 0.45002204, 0.40001959, 0.30001469, 0.30001469,
#         0.40001959, 0.30001469, 0.35001714, 0.45002204, 1.05005142]),
#  array([-9.99990207e-01, -8.00000000e-01, -6.00009793e-01, -4.00019587e-01,
#         -2.00029380e-01, -3.91732217e-05,  1.99951033e-01,  3.99941240e-01,
#          5.99931447e-01,  7.99921653e-01,  9.99911860e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.sin(np.arange(100)),orientation='vertical',density=True)
# Out:
# (array([1.00004897, 0.45002204, 0.40001959, 0.30001469, 0.30001469,
#         0.40001959, 0.30001469, 0.35001714, 0.45002204, 1.05005142]),
#  array([-9.99990207e-01, -8.00000000e-01, -6.00009793e-01, -4.00019587e-01,
#         -2.00029380e-01, -3.91732217e-05,  1.99951033e-01,  3.99941240e-01,
#          5.99931447e-01,  7.99921653e-01,  9.99911860e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.sin(np.arange(100)),density=True,cumulative =True)
# Out:
# (array([0.2 , 0.29, 0.37, 0.43, 0.49, 0.57, 0.63, 0.7 , 0.79, 1.  ]),
#  array([-9.99990207e-01, -8.00000000e-01, -6.00009793e-01, -4.00019587e-01,
#         -2.00029380e-01, -3.91732217e-05,  1.99951033e-01,  3.99941240e-01,
#          5.99931447e-01,  7.99921653e-01,  9.99911860e-01]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'A', 'B', 'C', 'D'
sizes = [15, 30, 45, 10]
explode = (0, 0.1,.1,.2)  # only "explode" the 2nd slice (i.e. 'Hogs')
plt.figure(figsize=(8,8))
plt.pie(sizes,  labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
# plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#         shadow=True, startangle=90)
plt.axis('equal')
# Out:
# (-1.1143898348979537,
#  1.1299557954617603,
#  -1.1258468317413044,
#  1.101230806657754)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
xval=np.arange(5)
yVal=np.arange(5,10)

# %%
X,Y=np.meshgrid(xval,yVal)

# %%
X = np.arange(-3, 3, 0.25)
Y = np.arange(-3, 3, 0.30)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.gca(projection='3d') # Get current axes
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,linewidth=0, antialiased=False)
plt.show()
# Out:
# <ipython-input-45-7c05ca6843ea>:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d') # Get current axes

# %%
matplotlib

seaborn
