# %%
import pandas as pd
import scipy.stats as scs

# %%
df = pd.read_csv('cs2M.csv')
df
# Out:
#      BP  Chlstrl  Age  Prgnt  AnxtyLH  DrugR
# 0   100      150   20      0        0      0
# 1   120      160   16      0        0      0
# 2   110      150   18      0        0      0
# 3   100      175   25      0        0      0
# 4    95      250   36      0        0      0
# 5   110      200   56      0        1      0
# 6   120      180   59      0        1      0
# 7   150      175   45      0        1      0
# 8   160      185   40      0        1      0
# 9   125      195   20      1        0      0
# 10  135      190   18      1        0      0
# 11  165      200   25      1        0      0
# 12  145      175   30      1        0      0
# 13  120      180   28      1        0      0
# 14  100      180   21      1        0      0
# 15  100      160   19      1        0      1
# 16   95      250   18      1        0      1
# 17  120      200   30      1        0      1
# 18  125      240   29      1        0      1
# 19  130      172   30      1        0      1
# ...

# %%
t_test = scs.ttest_1samp(df['Age'], popmean = 40)
print(t_test)
# Out:
# Ttest_1sampResult(statistic=-0.6508028129368016, pvalue=0.5202973762980163)

# %%
df2 = pd.read_csv('grades.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sr_No          105 non-null    int64
#  1   id             105 non-null    object
#  2   lastname       105 non-null    object
#  3   firstname      105 non-null    object
#  4   gender         105 non-null    int64
#  5   ethnicity      105 non-null    int64
#  6   year           105 non-null    int64
#  7   lowup          105 non-null    int64
#  8   section        105 non-null    int64
#  9   gpa            105 non-null    int64
#  10  extrc          105 non-null    int64
#  11  review         105 non-null    int64
#  12  quiz1          105 non-null    int64
#  13  quiz2          105 non-null    int64
#  14  quiz3          105 non-null    int64
#  15  quiz4          105 non-null    int64
#  16  quiz5          105 non-null    int64
#  17  final          105 non-null    int64
# ...

# %%
pair = scs.ttest_rel(df2['quiz1'],df2['quiz2'])
print(pair)
# Out:
# Ttest_relResult(statistic=-2.8717061192333544, pvalue=0.004948312027218486)
